# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
dataset = pd.read_csv(r"D:\jupyter programss\SampleforOrders.csv")
dataset.head(3)
# Out:
#       id  orderId                      createDate  storeId status orderStatus  \
# 0  10001  2838802  2022-06-17T08:23:06.717000000Z       31      S           S
# 1  10002  3478169  2022-06-17T08:46:10.407000000Z       31      X           M
# 2  10003  4916719  2022-06-17T08:46:54.700000000Z       31      X           M
#
#         partNumber  catalogEntryId                   catalogEntryName  \
# 0  MPHFU032_322001           14508  Stonehenge Lodraw Chest of drawer
# 1    HBA031_310101           14502            Klaus Silver Towel Rack
# 2  MPHFU032_322001           14508  Stonehenge Lodraw Chest of drawer
#
#    personTitle  ...                     shippedDate shippingCharge  \
# 0          NaN  ...  2022-06-23T18:30:00.000000000Z            NaN
# 1          NaN  ...                             NaN            NaN
# 2          NaN  ...                             NaN            NaN
#
#   shippingModeDescription  shippingModeId shippingOffset shippingTaxAmount  \
# ...

# %% [markdown]
# **Total number of rows and columns**

# %%
dataset.shape
# Out:
# (11, 52)

# %% [markdown]
# **Print data**

# %%
dataset
# Out:
#        id   orderId                      createDate  storeId status  \
# 0   10001   2838802  2022-06-17T08:23:06.717000000Z       31      S
# 1   10002   3478169  2022-06-17T08:46:10.407000000Z       31      X
# 2   10003   4916719  2022-06-17T08:46:54.700000000Z       31      X
# 3   10004   6040713  2022-06-17T08:47:32.955000000Z       31      X
# 4   10005   6040713  2022-06-17T08:47:41.588000000Z       31      X
# 5   10006   7147918  2022-06-17T09:10:18.462000000Z       31      X
# 6   10007   8192345  2022-06-17T09:11:23.556000000Z       31      X
# 7   10008   8926686  2022-06-17T09:17:34.177000000Z       31      S
# 8   10009   9578307  2022-06-17T09:31:07.194000000Z       31      S
# 9   10010  10890353  2022-06-17T10:10:08.107000000Z       31      M
# 10  10016  13470485  2022-06-17T11:08:23.841000000Z       31      S
#
#    orderStatus       partNumber  catalogEntryId  \
# 0            S  MPHFU032_322001           14508
# 1            M    HBA031_310101           14502
# ...

# %% [markdown]
# **To se all values of rows and columns**

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
dataset
# Out:
#        id   orderId                      createDate  storeId status  \
# 0   10001   2838802  2022-06-17T08:23:06.717000000Z       31      S
# 1   10002   3478169  2022-06-17T08:46:10.407000000Z       31      X
# 2   10003   4916719  2022-06-17T08:46:54.700000000Z       31      X
# 3   10004   6040713  2022-06-17T08:47:32.955000000Z       31      X
# 4   10005   6040713  2022-06-17T08:47:41.588000000Z       31      X
# 5   10006   7147918  2022-06-17T09:10:18.462000000Z       31      X
# 6   10007   8192345  2022-06-17T09:11:23.556000000Z       31      X
# 7   10008   8926686  2022-06-17T09:17:34.177000000Z       31      S
# 8   10009   9578307  2022-06-17T09:31:07.194000000Z       31      S
# 9   10010  10890353  2022-06-17T10:10:08.107000000Z       31      M
# 10  10016  13470485  2022-06-17T11:08:23.841000000Z       31      S
#
#    orderStatus       partNumber  catalogEntryId  \
# 0            S  MPHFU032_322001           14508
# 1            M    HBA031_310101           14502
# ...

# %% [markdown]
# **First 5 values**

# %%
dataset.head()
# Out:
#       id  orderId                      createDate  storeId status orderStatus  \
# 0  10001  2838802  2022-06-17T08:23:06.717000000Z       31      S           S
# 1  10002  3478169  2022-06-17T08:46:10.407000000Z       31      X           M
# 2  10003  4916719  2022-06-17T08:46:54.700000000Z       31      X           M
# 3  10004  6040713  2022-06-17T08:47:32.955000000Z       31      X           M
# 4  10005  6040713  2022-06-17T08:47:41.588000000Z       31      X           M
#
#         partNumber  catalogEntryId                   catalogEntryName  \
# 0  MPHFU032_322001           14508  Stonehenge Lodraw Chest of drawer
# 1    HBA031_310101           14502            Klaus Silver Towel Rack
# 2  MPHFU032_322001           14508  Stonehenge Lodraw Chest of drawer
# 3  MPHFU032_322001           14508  Stonehenge Lodraw Chest of drawer
# 4    HBA031_310101           14502            Klaus Silver Towel Rack
#
# ...

# %% [markdown]
# **To check null values**

# %%
dataset.isnull()
# Out:
#        id  orderId  createDate  storeId  status  orderStatus  partNumber  \
# 0   False    False       False    False   False        False       False
# 1   False    False       False    False   False        False       False
# 2   False    False       False    False   False        False       False
# 3   False    False       False    False   False        False       False
# 4   False    False       False    False   False        False       False
# 5   False    False       False    False   False        False       False
# 6   False    False       False    False   False        False       False
# 7   False    False       False    False   False        False       False
# 8   False    False       False    False   False        False       False
# 9   False    False       False    False   False        False       False
# 10  False    False       False    False   False        False       False
#
#     catalogEntryId  catalogEntryName  personTitle  firstName  lastName  \
# ...

# %% [markdown]
# _**Total null values in each column**_

# %%
dataset.isnull().sum()
# Out:
# id                               0
# orderId                          0
# createDate                       0
# storeId                          0
# status                           0
# orderStatus                      0
# partNumber                       0
# catalogEntryId                   0
# catalogEntryName                 0
# personTitle                     11
# firstName                        0
# lastName                         1
# email1                           0
# phone1                           0
# address1                         0
# address2                         0
# city                             1
# state                            0
# country                          1
# zipCode                          0
# adjustmentSum                    7
# allocatedFulfillmentCenterId     0
# allocatedQuantity                4
# comment                         11
# currency                         0
# description                     11
# displayAdjustment               11
# ...

# %% [markdown]
# **Total null values/data in overalldata**

# %%
dataset.isnull().sum().sum()
# Out:
# 155

# %% [markdown]
# **Drop column full of null value**

# %%
dataset.drop(columns="personTitle",inplace=True)

# %% [markdown]
# **To check total columns**

# %%
dataset.columns
# Out:
# Index(['id', 'orderId', 'createDate', 'storeId', 'status', 'orderStatus',
#        'partNumber', 'catalogEntryId', 'catalogEntryName', 'firstName',
#        'lastName', 'email1', 'phone1', 'address1', 'address2', 'city', 'state',
#        'country', 'zipCode', 'adjustmentSum', 'allocatedFulfillmentCenterId',
#        'allocatedQuantity', 'comment', 'currency', 'description',
#        'displayAdjustment', 'estimatedAvailableDate', 'fulfillmentCenterId',
#        'fulfillmentStatus', 'inventoryStatus', 'isExpedited',
#        'lastAllocatedUpdatedDate', 'neededQuantity', 'orderReleaseNumber',
#        'price', 'promisedAvailableDate', 'promisedShippingDate', 'quantity',
#        'releasedDate', 'requestedShipDate', 'shipmentTrackingNumber',
#        'shippedDate', 'shippingCharge', 'shippingModeDescription',
#        'shippingModeId', 'shippingOffset', 'shippingTaxAmount',
#        'totalAdjustment', 'totalProduct', 'totalShippingCharge', 'updateDate'],
#       dtype='object')

# %% [markdown]
# **Total null value present in column in percentage**

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
(dataset.isnull().sum()/(dataset.shape[0]))*100
# Out:
# id                                0.000000
# orderId                           0.000000
# createDate                        0.000000
# storeId                           0.000000
# status                            0.000000
# orderStatus                       0.000000
# partNumber                        0.000000
# catalogEntryId                    0.000000
# catalogEntryName                  0.000000
# firstName                         0.000000
# lastName                          9.090909
# email1                            0.000000
# phone1                            0.000000
# address1                          0.000000
# address2                          0.000000
# city                              9.090909
# state                             0.000000
# country                           9.090909
# zipCode                           0.000000
# adjustmentSum                    63.636364
# allocatedFulfillmentCenterId      0.000000
# allocatedQuantity                36.363636
# ...

# %% [markdown]
# **Total null data present in overall data in percentage**

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# 25.668449197860966

# %% [markdown]
# **Null values present through graphs**

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# **Drop the columns who have  100% or more than 50% null values**

# %%
dataset.drop(columns="comment",inplace=True)
dataset.drop(columns="description",inplace=True)
dataset.drop(columns="displayAdjustment",inplace=True)
dataset.drop(columns="promisedAvailableDate",inplace=True)
dataset.drop(columns="promisedShippingDate",inplace=True)
dataset.drop(columns="requestedShipDate",inplace=True)
dataset.drop(columns="shippingCharge",inplace=True)
dataset.drop(columns="shippingTaxAmount",inplace=True)
dataset.drop(columns="totalShippingCharge",inplace=True)

# %% [markdown]
# **After droping fully null columns**

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
dataset
# Out:
#        id   orderId                      createDate  storeId status  \
# 0   10001   2838802  2022-06-17T08:23:06.717000000Z       31      S
# 1   10002   3478169  2022-06-17T08:46:10.407000000Z       31      X
# 2   10003   4916719  2022-06-17T08:46:54.700000000Z       31      X
# 3   10004   6040713  2022-06-17T08:47:32.955000000Z       31      X
# 4   10005   6040713  2022-06-17T08:47:41.588000000Z       31      X
# 5   10006   7147918  2022-06-17T09:10:18.462000000Z       31      X
# 6   10007   8192345  2022-06-17T09:11:23.556000000Z       31      X
# 7   10008   8926686  2022-06-17T09:17:34.177000000Z       31      S
# 8   10009   9578307  2022-06-17T09:31:07.194000000Z       31      S
# 9   10010  10890353  2022-06-17T10:10:08.107000000Z       31      M
# 10  10016  13470485  2022-06-17T11:08:23.841000000Z       31      S
#
#    orderStatus       partNumber  catalogEntryId  \
# 0            S  MPHFU032_322001           14508
# 1            M    HBA031_310101           14502
# ...

# %%
dataset.shape
# Out:
# (11, 42)

# %% [markdown]
# **After droping null value percentage in each column**

# %%
(dataset.isnull().sum()/(dataset.shape[0]))*100
# Out:
# id                               0.000000
# orderId                          0.000000
# createDate                       0.000000
# storeId                          0.000000
# status                           0.000000
# orderStatus                      0.000000
# partNumber                       0.000000
# catalogEntryId                   0.000000
# catalogEntryName                 0.000000
# firstName                        0.000000
# lastName                         9.090909
# email1                           0.000000
# phone1                           0.000000
# address1                         0.000000
# address2                         0.000000
# city                             9.090909
# state                            0.000000
# country                          9.090909
# zipCode                          0.000000
# adjustmentSum                   63.636364
# allocatedFulfillmentCenterId     0.000000
# allocatedQuantity               36.363636
# ...

# %% [markdown]
# **After droping columns overall null value in data in percentage**

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# 9.740259740259742

# %% [markdown]
# **After droping columns overall null value in data in graph**

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **dropna will drop all rows who have missing values**

# %%
#dataset.dropna(inplace=True)
#sns.heatmap(dataset.isnull())
#plt.show

# %%
dataset.drop(columns="shipmentTrackingNumber",inplace=True)
dataset.drop(columns="shippedDate",inplace=True)
dataset.drop(columns="adjustmentSum",inplace=True)
dataset.drop(columns="totalAdjustment",inplace=True)
dataset.drop(columns="orderReleaseNumber",inplace=True)
dataset.drop(columns="releasedDate",inplace=True)
dataset.drop(columns="allocatedQuantity",inplace=True)

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# 0.7792207792207793

# %%
dataset.isnull().sum()
# Out:
# id                              0
# orderId                         0
# createDate                      0
# storeId                         0
# status                          0
# orderStatus                     0
# partNumber                      0
# catalogEntryId                  0
# catalogEntryName                0
# firstName                       0
# lastName                        1
# email1                          0
# phone1                          0
# address1                        0
# address2                        0
# city                            1
# state                           0
# country                         1
# zipCode                         0
# allocatedFulfillmentCenterId    0
# currency                        0
# estimatedAvailableDate          0
# fulfillmentCenterId             0
# fulfillmentStatus               0
# inventoryStatus                 0
# isExpedited                     0
# lastAllocatedUpdatedDate        0
# ...

# %%
dataset.shape
# Out:
# (11, 35)

# %% [markdown]
# **Axis 0 − Axis 0 refers to the rows of a data frame or a Series. It is often referred to as the "index axis". When an operation is applied along axis 0, it means that the operation is applied to each row of the Data Frame or Series. Axis 1 − Axis 1 refers to the columns of a data frame or a Series.**

# %%
dataset.fillna(method="ffill",axis=0)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20000\419294573.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="ffill",axis=0)
#        id   orderId                      createDate  storeId status  \
# 0   10001   2838802  2022-06-17T08:23:06.717000000Z       31      S
# 1   10002   3478169  2022-06-17T08:46:10.407000000Z       31      X
# 2   10003   4916719  2022-06-17T08:46:54.700000000Z       31      X
# 3   10004   6040713  2022-06-17T08:47:32.955000000Z       31      X
# 4   10005   6040713  2022-06-17T08:47:41.588000000Z       31      X
# 5   10006   7147918  2022-06-17T09:10:18.462000000Z       31      X
# 6   10007   8192345  2022-06-17T09:11:23.556000000Z       31      X
# 7   10008   8926686  2022-06-17T09:17:34.177000000Z       31      S
# 8   10009   9578307  2022-06-17T09:31:07.194000000Z       31      S
# ...

# %%
dataset.isnull().sum()
# Out:
# id                              0
# orderId                         0
# createDate                      0
# storeId                         0
# status                          0
# orderStatus                     0
# partNumber                      0
# catalogEntryId                  0
# catalogEntryName                0
# firstName                       0
# lastName                        0
# email1                          0
# phone1                          0
# address1                        0
# address2                        0
# city                            0
# state                           0
# country                         0
# zipCode                         0
# allocatedFulfillmentCenterId    0
# currency                        0
# estimatedAvailableDate          0
# fulfillmentCenterId             0
# fulfillmentStatus               0
# inventoryStatus                 0
# isExpedited                     0
# lastAllocatedUpdatedDate        0
# ...

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# 0.0

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
